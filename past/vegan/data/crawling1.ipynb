# %%
import requests
import time

endpoint = "https://apis.data.go.kr/1390803/AgriFood/FdFoodCkry/getKoreanFoodFdFoodCkryList"
service_key = "f25c7a1339be9d6656ead6381c4dd690ed8a829230eef344d2650296c9675fee"

# 'https://apis.data.go.kr/1390803/AgriFood/FdFoodCkry/getKoreanFoodFdFoodCkryList?serviceKey=f25c7a1339be9d6656ead6381c4dd690ed8a829230eef344d2650296c9675fee'
# '&service_Type=xml&Page_No=1' \
#   -H 'accept: */*'


params = {
    "serviceKey": service_key,
    "service_Type": "xml", 
    "Page_No": '1',
    "Page_Size": '10'
}

res = requests.get(endpoint, params=params)

print(res.status_code)
print(res.headers.get("Content-Type"))
print(res.text)
# Out:
# 200
# text/xml; charset=UTF-8
# <?xml version="1.0" encoding="UTF-8" standalone="yes" ?>
# <response>
# <header>
# <result_Code>200</result_Code>
# <result_Msg>OK</result_Msg>
# </header>
# <body>
# <rcdcnt>10</rcdcnt><page_No>1</page_No>
# <total_Count>3250</total_Count>
# <items>
# <item>
# <no>1</no>
# <fd_Code>D011001</fd_Code>
# <upper_Fd_Grupp_Nm>밥류</upper_Fd_Grupp_Nm>
# <fd_Grupp_Nm>쌀밥</fd_Grupp_Nm>
# <fd_Nm>눌은밥</fd_Nm>
# <fd_Wgh>440.00</fd_Wgh>
# <food_Cnt>1</food_Cnt>
# <food_List>
# <food>
# <fd_Code>D011001</fd_Code>
# <food_Code>F00093</food_Code>
# <food_Nm>즉석밥, 누룽지, 끓는물 부음</food_Nm>
# <food_Eng_Nm>Instant cooked rice, Scorched rice(Nurungji), White, Hot water added</food_Eng_Nm>
# <nation_Std_Food_Grupp_Code_Nm>곡류 및 그 제품</nation_Std_Food_Grupp_Code_Nm>
# <origin_Code_Nm>농진청</origin_Code_Nm>
# <food_Wgh>440.00</food_Wgh>
# <allrgy_Info>null</allrgy_Info>
# <onslf_Std_Food_Grupp_Nm>null</onslf_Std_Food_Grupp_Nm>
# <amplt_Cl_Nm>null</amplt_Cl_Nm>
# </food>
# </food_List>
# ...
